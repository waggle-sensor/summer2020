# %% [markdown]
# # Plot LSTM Weather Data Test Results

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set()

# %%
low = [0.86,0.91,0.89,0.83,0.78,0.74]
mid = [0.56,0.67,0.60,0.52,0.45,0.42]
high = [0.92,0.93,0.91,0.92,0.91,0.91]
acc = [0.84,0.87,0.85,0.82,0.79,0.77]

# %%
fig, ax = plt.subplots()
plt.plot([15,30,45,60,75,90],acc, linestyle='--', marker='o', color='orange')
plt.title('Results of Nowcasting Net Radiation \n with Weather Sensor Test',fontsize=16)
plt.ylabel('Accuracy',fontsize=14)
plt.xlabel('Time in Minuets',fontsize=14)
plt.savefig("WeatherDataTestResultsPaper_pic.jpg")
